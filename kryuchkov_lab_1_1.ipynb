# %% [markdown]
# <a href="https://colab.research.google.com/github/kryuchkov-sr/python-workshop/blob/main/kryuchkov_lab_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Выполнил: Крючков Сергей <br> Группа: АБП-231**

# %% [markdown]
# **1.1.1 Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:**<br>
# •	арифметические: +, -, * , / , // , %, **; <br>
# •	сравнение: <, <=, >, >=, !=, ==, <br>
# выводя на экран результат каждого действия. В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).

# %%
# Задание task_01_01.
# Выполнил: Крючков Сергей
# Группа: АБП-231

a = int(input("a="))
b = int(input("b="))
print(a+b)
print(a-b)
print(a*b)
print(round(a/b,2))
print(a//b)
print(a%b)
print(a**b)
print(a<b)
print(a<=b)
print(a>b)
print(a>=b)
print(a!=b)
print(a==b)

# --------------
# Пример вывода:
#
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_02.
# Выполнил: Крючков Сергей
# Группа: АБП-231

x = int(input("x="))
y = int(input("y="))
z = int(input("z="))
res = round((((x**5 + 7)**1/3) / ((y*abs(-6))**1/3)) / (7 - z%y),3)
print(res)

# --------------
# Пример вывода:
#
# x=0
# y=1
# z=2
# 0.15
# Out:
# x=0
# y=1
# z=2
# 0.167

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_03.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# Сопротивление первого проводника
r1 = float(input("r1="))
# Сопротивление второго проводника
r2 = float(input("r2="))

# Общее сопротивление
r = r1 + r2
print(r)

# --------------
# Пример вывода:
#
# r1=12.2
# r2=16.1
# 28.3
# Out:
# r1=12.2
# r2=16.1
# 28.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_04.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# Двузначное число
num2 = int(input("Двузначное число: "))
# Трехзначное число
num3 = int(input("Трёхзначное число: "))

# 1-я цифра числа 'num2'
num2_1 = num2 // 10
# 2-я цифра числа 'num2'
num2_2 = num2 % 10

# Сумма цифр числа 'num2'
num2_s = num2_1 + num2_2
# Произведение цифр числа 'num2'
num2_p = num2_1 * num2_2

# 1-я цифра числа 'num3'
num3_1 = num3 // 100
# 2-я цифра числа 'num3'
num3_2 = num3 // 10 % 10
# 3-я цифра числа 'num3'
num3_3 = num3 % 10

# Сумма цифр числа 'num3'
num3_s = num3_1 + num3_2 + num3_3
# Произведение цифр числа 'num3'
num3_p = num3_1 * num3_2 * num3_3

# Вывод результата
print("Сумма и произведение цифр двузначного числа:", num2_s, num2_p)
print("Сумма и произведение цифр трёхзначного числа:", num3_s, num3_p)

# --------------
# Пример вывода:
#
# Двузначное число: 45
# Трехзначное число: 456
# Сумма и произведение цифр двузначного числа: 9 20
# Сумма и произведение цифр трехзначного числа: 15 120
# Out:
# Двузначное число: 45
# Трёхзначное число: 456
# Сумма и произведение цифр двузначного числа: 9 20
# Сумма и произведение цифр трёхзначного числа: 15 120

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_05.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# Количество минут
m = int(input("Количество минут, прошедшее с начала суток: "))

# Количество часов, прошедших с начала суток
h = m // 60
# Количество минут, прошедших с момента начала последнего часа
m2 = m % 60

# Вывод результатов
print("Количество часов, прошедших с начала суток: ", h)
print("Количество минут, прошедшее с начала последнего часа: ", m2)

# --------------
# Пример вывода:
#
# Количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток: 2
# Количество минут, прошедших с момента начала последнего часа: 3
# Out:
# Количество минут, прошедшее с начала суток: 123
# Количество часов, прошедших с начала суток:  2
# Количество минут, прошедшее с начала последнего часа:  3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_06.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# ввод неизвестных величин
a = int(input("Введите a = "))
b = int(input("Введите b = "))
m = int(input("Введите m = "))
n = int(input("Введите n = "))

# определение корня уровнения
x = (- b) / a

# логическое выражение попадания корня в область
is_ok = m <= x <= n

# вывод результата
print("Попадает:", is_ok)


# --------------
# Пример вывода:
#
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True
# Out:
# Введите a = 1
# Введите b = 2
# Введите m = -5
# Введите n = 5
# Попадает: True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_07.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# вывод названия команды с надписью '- чемпион!'
team = input("Введите название команды: ")
print(team, "- чемпион!")

# вывод строки из '-' длиной как название команды
cherta = len(team) * "-"
print(cherta)

# Название команды в нижнем регистре
team_lowercase =  team.lower()
print(team_lowercase)

# длина наименования команды
print("Символов в названии команды: ", len(team))

# проверка на букву 'п'
print("Буква 'п' есть: ", "п" in team.lower())

# сколько раз повторяется "а"
print("Количество букв 'а': ", team.lower().count("а"))


# --------------
# Пример вывода:
#
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# Символов в названии команды: 7
# Буква "п" есть: True
# Количество букв "а": 2
# Out:
# Введите название команды: Спартак
# Спартак - чемпион!
# -------
# спартак
# Символов в названии команды:  7
# Буква 'п' есть:  True
# Количество букв 'а':  2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_08.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# Название государства
country = input("Введите название государства: ")
# Название столицы
capital = input("Введите название столицы: ")

print("Государство - {0}, столица - {1}".format(country, capital))


# --------------
# Пример вывода:
#
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва
# Out:
# Введите название государства: Россия
# Введите название столицы: Москва
# Государство - Россия, столица - Москва

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_09.
# Выполнил: Крючков Сергей
# Группа: АБП-231

word = "объектно-ориентированный"

w1 = word[:6]  # (слово объект)
w2 = word [9:17] # (слово ориентир)
w3 = word [14:17] # (слово тир)
w4 = word [4] + word [7] + word [5] # (слово кот)
w5 = word [10] + word [12:15] + word [19] # (слово рента)

print(w1, w2, w3, w4, w5, sep="\n")


# --------------
# Пример вывода:
#
# объект
# ориентир
# тир
# кот
# рента
# Out:
# объект
# ориентир
# тир
# кот
# рента

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_10.
# Выполнил: Крючков Сергей
# Группа: АБП-231

# Создать 2 пустых списка
a = []
b = []
# Добавить 2 вещественных числа (4.5 и 3.4) в список 'a' с помощью append
a.append(4.5)
a.append(3.4)

# Добавить 2 вещественных числа (8.7, 1.3) в список 'a' с помощью extend
a.extend([8.7, 1.3])

# Добавить 2 вещественных числа (14.5, 3.4) в список 'b' с помощью append
# Удалите комментарий и допишите код
b.append(14.5)
b.append(3.4)

# Добавить 2 вещественных числа (8.7, 11.3) в список 'b'с помощью extend
b.extend([8.7, 11.3])

# Вставить целое число 100 на 2-е и 4-е место списка 'a'
a.insert(1, 100)
a.insert(3, 100)

# Вставить целое число 200 на 1-е и 3-е место списка 'b'
b.insert(0, 200)
b.insert(2, 200)

# Вывести списки на экран
print("Исходные списки:")
print("1-й: ", a)
print("2-й: ", b)

# Удалить первые элементы из списков 'a' и 'b'
del a [0]
del b [0]

# Удалить элемент 100 из списка 'a'
a.remove(100)
# Удалить элемент 200 из списка 'b
b.remove(200)

# Вывести списки на экран
print("\nПосле удалений:")
print("1-й: ", a)
print("2-й: ", b)

# Создать множества из списков 'a' и 'b', а также их пересечение
sa = set(a)
sb = set(b)
sa_and_sb = sa & sb

# Вывести экран уникальные элементы каждого списка и общие
print("\nУникальные элементы:")
print("1-й: ", sa)
print("2-й: ", sb)
print("общие:", sa_and_sb)

# Соединить списки 'a' и 'b'
c = a + b

# Отсортировать список 'c' по возрастанию и убыванию
c_asc = sorted(c)
c_desc = sorted(c, reverse = True)

# Среднее арифметическое элементов списка 'c', расположенных на четных местах
even_elements = [c[i] for i in range(1, len(c), 2)]
sr_ar = sum(even_elements) / len(even_elements) if even_elements else 0

# Среднее геометрическое элементов списка 'c', расположенных на нечетных местах
odd_elements = [c[i] for i in range(0, len(c), 2)]

product = 1.0
for x in odd_elements:
    product *= x

n = len(odd_elements)
sr_geom = round(product ** (1/n) if n > 0 else 0, 2)

# Максимальный и минимальный элементы
c_max = max(c)
c_min = min(c)

# Вывести результаты на экран
print("\nИтоговые:")
print("3-й: ", c)
print("Сортировка (возр.): ", c_asc)
print("Сортировка (убыв.): ", c_desc)
print("Ср. арифм. = ", sr_ar, ", ср. геометр. = ", sr_geom)
print("Макс. и мин.: ", c_max, c_min)

# --------------
# Пример вывода:
#
# Исходные списки:
# 1-й: [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й: [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# 1-й: [3.4, 100, 8.7, 1.3]
# 2-й: [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й: {8.7, 1.3, 3.4, 100}
# 2-й: {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й: [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.): [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.): [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. = 29.00, ср. геометр. = 7.82
# Макс. и мин.: 100 1.3
# Out:
# Исходные списки:
# 1-й:  [4.5, 100, 3.4, 100, 8.7, 1.3]
# 2-й:  [200, 14.5, 200, 3.4, 8.7, 11.3]
#
# После удалений:
# 1-й:  [3.4, 100, 8.7, 1.3]
# 2-й:  [14.5, 3.4, 8.7, 11.3]
#
# Уникальные элементы:
# 1-й:  {8.7, 1.3, 3.4, 100}
# 2-й:  {8.7, 11.3, 3.4, 14.5}
# общие: {8.7, 3.4}
#
# Итоговые:
# 3-й:  [3.4, 100, 8.7, 1.3, 14.5, 3.4, 8.7, 11.3]
# Сортировка (возр.):  [1.3, 3.4, 3.4, 8.7, 8.7, 11.3, 14.5, 100]
# Сортировка (убыв.):  [100, 14.5, 11.3, 8.7, 8.7, 3.4, 3.4, 1.3]
# Ср. арифм. =  29.0 , ср. геометр. =  7.82
# Макс. и мин.:  100 1.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Задание task_01_11.
# Выполнил: Крючков Сергей
# Группа: АБП-231


# В данной задаче все значения задаются в коде (без input())

# 1. Создание словаря
# Создать пустой словарь
info = {}

# Добавить значения для ключей "фио", "дата_рождения", "место_рождения"
info["фио"] = "Иванов Иван Иванович"
info["дата_рождения"] = "01/09/1995"
info["место_рождения"] = "Париж"

# Напечатать словарь
print(info)

# Создать ключ "хобби" со значением = список из строк
info["хобби"] = ["игра на гитаре", "туризм"]

# Добавить "программирование" в список хобби
info["хобби"].append("программирование")

# Создать ключ "животные" со значением = кортеж из строк
info["животные"] = ("кошка Мурка",)

# Создать ключ "ЕГЭ" и поместить в него пустой словарь
info["ЕГЭ"] = {}

# В словарь info["ЕГЭ"] добавить информацию о сданных экзаменах
info["ЕГЭ"]["Математика"] = 90
info["ЕГЭ"]["Информатика"] = 88
info["ЕГЭ"]["Русский язык"] = 67

# Добавить экзамен, который не был сдан, после чего удалить его
info["ЕГЭ"]["Физика"] = 0
del info["ЕГЭ"]["Физика"]

# Создать ключ "вузы" и поместить в него пустой словарь
info["вузы"] = {}

# В словарь info["вузы"] добавить информацию о вузах
info["вузы"]["МИРЭА"] = 240
info["вузы"]["МГУ"] = 295
info["вузы"]["МГТУ им. Баумана"] = 255

# 2. Вывод на экран
print("Данные:")
# Получившийся словарь
print(info)

# Список экзаменов ЕГЭ в алфавитном порядке
exams = tuple(sorted(info["ЕГЭ"].keys()))
print("Предметы:", exams)

# Список вузов в алфавитном порядке
uni = tuple(sorted(info["вузы"].keys()))
print("Вузы:", uni)

# 3. Ответы на вопросы
print("\nОтветы на вопросы:")

# Выделить имя из info["фио"]
name = info["фио"].split()[1]  # "Иван"

# Начинается на гласную? (True/False)
starts_with_vowel = name[0].lower() in "аеёиоуыэюя"
print("* мое имя начинается на гласную букву:", starts_with_vowel)

# Выделить месяц из info["дата_рождения"]
month = int(info["дата_рождения"].split("/")[1])  # 9

# Родился зимой или летом? (True/False)
# Зима: 12, 1, 2; Лето: 6, 7, 8
born_in_winter_or_summer = month in [12, 1, 2, 6, 7, 8]
print("* родился летом или зимой:", born_in_winter_or_summer)

# Количество хобби и первое из них
hobbies_count = len(info["хобби"])
first_hobby = info["хобби"][0]
print("* у меня {} хобби, первое \"{}\"".format(hobbies_count, first_hobby))

# Количество сданных экзаменов
exam_count = len(info["ЕГЭ"])
print("* после окончания школы сдавал {} экз.".format(exam_count))

# Сумма баллов по экзаменам
sum_mark = sum(info["ЕГЭ"].values())
print("* сумма баллов = {}".format(sum_mark))

# Максимальный балл среди сданных
max_mark = max(info["ЕГЭ"].values())
print("* макс. балл = {}".format(max_mark))

# Количество вузов, в которые Вы проходите по баллам
vuz_count = sum(1 for bal in info["вузы"].values() if sum_mark >= bal)
print("* кол-во вузов в которые прохожу: {}".format(vuz_count))




# --------------
# Пример вывода:
#
# {'фио': 'Иванов Иван Иванович', 'место_рождения': 'Париж',
#  'дата_рождения': '01/09/1995'}
# Данные:
# {'фио': 'Иванов Иван Иванович', 'животные': ('кошка Мурка',),
#  'вузы': {'МИРЭА': 240, 'МГУ': 295, 'МГТУ им. Баумана': 255},
#  'хобби': ['игра на гитаре', 'туризм', 'программирование'],
#  'ЕГЭ': {'Математика': 90, 'Информатика': 88, 'Русский язык': 67},
#  'дата_рождения': '01/09/1995', 'место_рождения': 'Париж'}
# Предметы: Информатика, Математика, Русский язык
# Вузы: МГТУ им. Баумана, МГУ, МИРЭА

# Ответы на вопросы:
# * мое имя начинается на гласную букву: True
# * родился летом или зимой: False
# * у меня 3 хобби, первое "игра на гитаре"
# * после окончания школы сдавал 3 экз.
# * сумма баллов = 245
# * макс. балл = 90
# * кол-во вузов в которые прохожу: 1
# Out:
# {'фио': 'Иванов Иван Иванович', 'дата_рождения': '01/09/1995', 'место_рождения': 'Париж'}
# Данные:
# {'фио': 'Иванов Иван Иванович', 'дата_рождения': '01/09/1995', 'место_рождения': 'Париж', 'хобби': ['игра на гитаре', 'туризм', 'программирование'], 'животные': ('кошка Мурка',), 'ЕГЭ': {'Математика': 90, 'Информатика': 88, 'Русский язык': 67}, 'вузы': {'МИРЭА': 240, 'МГУ': 295, 'МГТУ им. Баумана': 255}}
# Предметы: ('Информатика', 'Математика', 'Русский язык')
# Вузы: ('МГТУ им. Баумана', 'МГУ', 'МИРЭА')
#
# Ответы на вопросы:
# * мое имя начинается на гласную букву: True
# * родился летом или зимой: False
# * у меня 3 хобби, первое "игра на гитаре"
# * после окончания школы сдавал 3 экз.
# * сумма баллов = 245
# * макс. балл = 90
# * кол-во вузов в которые прохожу: 1
